# %%
from TorchSpatial.utils.datasets import load_dataset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from datasets import load_dataset
#
# File ~/Downloads/TorchSpatial/utils/datasets.py:10
#       6 import sys
#       8 from paths import get_paths
# ---> 10 from data_utils import *
#      13 def load_dataset(
#      14     params,
#      15     eval_split,
#    (...)     20     load_cnn_features_train=False,
#      21 ):
#      22     """
#      23     Args:
#      24         params: the input paramters
#    (...)     30
#      31     """
#
# File ~/Downloads/TorchSpatial/utils/data_utils.py:10
#       6 import os
#       8 import numpy as np
# ---> 10 from .paths import *
#      13 def make_model_res_file(
#      14     data_dir, dataset="inat2018", eval_split="val", res_type="preds", sample_ratio=None
#      15 ):
#      16     assert eval_split in ["train", "val", "test"]
#
# ...

# %%
params = {"dataset": "birdsnap", "meta_type": "location", }
eval_split = "train"
train_remove_invalid = True
eval_remove_invalid = True

# %%
load_dataset(params = params,
    eval_split = eval_split,
    train_remove_invalid = train_remove_invalid,
    eval_remove_invalid = eval_remove_invalid,
    load_cnn_predictions=False,
    load_cnn_features=False,
    load_cnn_features_train=False,)
